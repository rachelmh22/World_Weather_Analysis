# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eae6741fe514cd595acbb7046ce93c6b

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_weather = requests.get(url).json()
print (city_weather)
# Out:
# {'cod': '400', 'message': 'Nothing to geocode'}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

        # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | quijingue
# Processing Record 2 of Set 1 | high level
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | kosamba
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | gamba
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | olinda
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | clyde river
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | lengshuijiang
# Processing Record 16 of Set 1 | havelock
# Processing Record 17 of Set 1 | pombal
# Processing Record 18 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 1 | yulara
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | padang
# Processing Record 22 of Set 1 | zasheyek
# Processing Record 23 of Set 1 | ambilobe
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | isangel
# Processing Record 26 of Set 1 | ancud
# Processing Record 27 of Set 1 | atbasar
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | comodoro rivadavia
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | severo-kurilsk
# Processing Record 34 of Set 1 | pisco
# Processing Record 35 of Set 1 | pecos
# Processing Record 36 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 1 | manoel urbano
# Processing Record 38 of Set 1 | moissala
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | saint-pierre
# Processing Record 42 of Set 1 | dunedin
# Processing Record 43 of Set 1 | buala
# Processing Record 44 of Set 1 | nevelsk
# Processing Record 45 of Set 1 | atambua
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | curup
# Processing Record 49 of Set 1 | sabang
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | sapouy
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | fairbanks
# Processing Record 8 of Set 2 | lorengau
# Processing Record 9 of Set 2 | helong
# Processing Record 10 of Set 2 | osmanabad
# Processing Record 11 of Set 2 | shitanjing
# Processing Record 12 of Set 2 | yaan
# Processing Record 13 of Set 2 | tres picos
# Processing Record 14 of Set 2 | griffith
# Processing Record 15 of Set 2 | mezen
# Processing Record 16 of Set 2 | poshekhonye
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | mae hong son
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | sisimiut
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | henties bay
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | san patricio
# Processing Record 28 of Set 2 | plast
# Processing Record 29 of Set 2 | grand gaube
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | nelson bay
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | egvekinot
# Processing Record 35 of Set 2 | maniitsoq
# Processing Record 36 of Set 2 | bonfim
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | maceio
# Processing Record 39 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 40 of Set 2 | kununurra
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | ginda
# Processing Record 45 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 2 | port blair
# Processing Record 47 of Set 2 | kovur
# Processing Record 48 of Set 2 | myitkyina
# Processing Record 49 of Set 2 | yinchuan
# Processing Record 50 of Set 2 | batagay-alyta
# Processing Record 1 of Set 3 | naliya
# Processing Record 2 of Set 3 | nemuro
# Processing Record 3 of Set 3 | plettenberg bay
# Processing Record 4 of Set 3 | kikwit
# Processing Record 5 of Set 3 | muros
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | mayo
# Processing Record 10 of Set 3 | rensvik
# Processing Record 11 of Set 3 | poum
# Processing Record 12 of Set 3 | aklavik
# Processing Record 13 of Set 3 | provideniya
# Processing Record 14 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 3 | seoul
# Processing Record 16 of Set 3 | sao joao da barra
# Processing Record 17 of Set 3 | bilibino
# Processing Record 18 of Set 3 | verkhoyansk
# Processing Record 19 of Set 3 | laguna
# Processing Record 20 of Set 3 | saskylakh
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | chara
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | bud
# Processing Record 26 of Set 3 | christchurch
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | drakino
# Processing Record 29 of Set 3 | mount gambier
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | qui nhon
# Processing Record 32 of Set 3 | prince rupert
# Processing Record 33 of Set 3 | sovetskiy
# Processing Record 34 of Set 3 | beringovskiy
# Processing Record 35 of Set 3 | rio branco
# Processing Record 36 of Set 3 | codrington
# Processing Record 37 of Set 3 | hualmay
# Processing Record 38 of Set 3 | coquimbo
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | rayevskiy
# Processing Record 41 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 3 | ushtobe
# Processing Record 43 of Set 3 | nouadhibou
# Processing Record 44 of Set 3 | constitucion
# Processing Record 45 of Set 3 | kamenka
# Processing Record 46 of Set 3 | mackay
# Processing Record 47 of Set 3 | mar del plata
# Processing Record 48 of Set 3 | mangochi
# Processing Record 49 of Set 3 | palm coast
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | san vicente
# Processing Record 2 of Set 4 | mangrol
# Processing Record 3 of Set 4 | sirfa
# City not found. Skipping...
# Processing Record 4 of Set 4 | ponta delgada
# Processing Record 5 of Set 4 | batemans bay
# Processing Record 6 of Set 4 | praia
# Processing Record 7 of Set 4 | kurmanayevka
# Processing Record 8 of Set 4 | saint-philippe
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | hermanus
# Processing Record 11 of Set 4 | bubaque
# Processing Record 12 of Set 4 | marawi
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | mogochin
# City not found. Skipping...
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | te anau
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | bulungu
# Processing Record 19 of Set 4 | pangkalanbuun
# Processing Record 20 of Set 4 | bajos de haina
# Processing Record 21 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 4 | betafo
# Processing Record 23 of Set 4 | southbridge
# Processing Record 24 of Set 4 | pevek
# Processing Record 25 of Set 4 | hami
# Processing Record 26 of Set 4 | kaitangata
# Processing Record 27 of Set 4 | butaritari
# Processing Record 28 of Set 4 | acarau
# Processing Record 29 of Set 4 | korhogo
# Processing Record 30 of Set 4 | vardo
# Processing Record 31 of Set 4 | camopi
# Processing Record 32 of Set 4 | vostok
# Processing Record 33 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 4 | oshikango
# Processing Record 35 of Set 4 | torquay
# Processing Record 36 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 37 of Set 4 | lichinga
# Processing Record 38 of Set 4 | yerofey pavlovich
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | kavaratti
# Processing Record 41 of Set 4 | college
# Processing Record 42 of Set 4 | tshikapa
# Processing Record 43 of Set 4 | zambezi
# Processing Record 44 of Set 4 | namatanai
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | lebu
# Processing Record 47 of Set 4 | cutro
# Processing Record 48 of Set 4 | bozhou
# Processing Record 49 of Set 4 | cherskiy
# Processing Record 50 of Set 4 | fortuna
# Processing Record 1 of Set 5 | inhambane
# Processing Record 2 of Set 5 | vao
# Processing Record 3 of Set 5 | grindavik
# Processing Record 4 of Set 5 | iqaluit
# Processing Record 5 of Set 5 | kormilovka
# Processing Record 6 of Set 5 | longonjo
# Processing Record 7 of Set 5 | svetlyy
# Processing Record 8 of Set 5 | valparaiso
# Processing Record 9 of Set 5 | vilhena
# Processing Record 10 of Set 5 | port macquarie
# Processing Record 11 of Set 5 | kavieng
# Processing Record 12 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 5 | lagoa
# Processing Record 14 of Set 5 | akyab
# Processing Record 15 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | jamestown
# Processing Record 19 of Set 5 | castro
# Processing Record 20 of Set 5 | santa rosa
# Processing Record 21 of Set 5 | navalmoral de la mata
# Processing Record 22 of Set 5 | avarua
# Processing Record 23 of Set 5 | genhe
# Processing Record 24 of Set 5 | awbari
# Processing Record 25 of Set 5 | bambous virieux
# Processing Record 26 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | lasa
# Processing Record 28 of Set 5 | shimoda
# Processing Record 29 of Set 5 | nha trang
# Processing Record 30 of Set 5 | ribeira grande
# Processing Record 31 of Set 5 | howell
# Processing Record 32 of Set 5 | adamovka
# Processing Record 33 of Set 5 | liverpool
# Processing Record 34 of Set 5 | puerto ayacucho
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | iracoubo
# Processing Record 37 of Set 5 | mizan teferi
# Processing Record 38 of Set 5 | sioux lookout
# Processing Record 39 of Set 5 | pitimbu
# Processing Record 40 of Set 5 | kulhudhuffushi
# Processing Record 41 of Set 5 | omsukchan
# Processing Record 42 of Set 5 | srednekolymsk
# Processing Record 43 of Set 5 | qasigiannguit
# Processing Record 44 of Set 5 | hay river
# Processing Record 45 of Set 5 | cayenne
# Processing Record 46 of Set 5 | burica
# City not found. Skipping...
# Processing Record 47 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 5 | bang saphan
# Processing Record 49 of Set 5 | katangli
# Processing Record 50 of Set 5 | bethel
# Processing Record 1 of Set 6 | anadyr
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | pithapuram
# Processing Record 4 of Set 6 | tuatapere
# Processing Record 5 of Set 6 | breyten
# Processing Record 6 of Set 6 | sinnamary
# Processing Record 7 of Set 6 | hasaki
# Processing Record 8 of Set 6 | pacific grove
# Processing Record 9 of Set 6 | pangnirtung
# Processing Record 10 of Set 6 | paamiut
# Processing Record 11 of Set 6 | beira
# Processing Record 12 of Set 6 | marzuq
# Processing Record 13 of Set 6 | tigil
# Processing Record 14 of Set 6 | ahipara
# Processing Record 15 of Set 6 | stornoway
# Processing Record 16 of Set 6 | iglesias
# Processing Record 17 of Set 6 | barrow
# Processing Record 18 of Set 6 | alyangula
# Processing Record 19 of Set 6 | pauini
# Processing Record 20 of Set 6 | manicore
# Processing Record 21 of Set 6 | porto novo
# Processing Record 22 of Set 6 | itarema
# Processing Record 23 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 6 | kang
# Processing Record 25 of Set 6 | wanning
# Processing Record 26 of Set 6 | lompoc
# Processing Record 27 of Set 6 | passo de camaragibe
# Processing Record 28 of Set 6 | vuktyl
# Processing Record 29 of Set 6 | pemangkat
# Processing Record 30 of Set 6 | cidreira
# Processing Record 31 of Set 6 | pochutla
# Processing Record 32 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 6 | maragogi
# Processing Record 34 of Set 6 | dingle
# Processing Record 35 of Set 6 | pampa
# Processing Record 36 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 6 | jinxiang
# Processing Record 38 of Set 6 | great falls
# Processing Record 39 of Set 6 | broome
# Processing Record 40 of Set 6 | kirakira
# Processing Record 41 of Set 6 | marsh harbour
# Processing Record 42 of Set 6 | oussouye
# Processing Record 43 of Set 6 | carballo
# Processing Record 44 of Set 6 | yarmouth
# Processing Record 45 of Set 6 | la ronge
# Processing Record 46 of Set 6 | nara
# Processing Record 47 of Set 6 | destin
# Processing Record 48 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 6 | banikoara
# Processing Record 50 of Set 6 | maldonado
# Processing Record 1 of Set 7 | bandiagara
# Processing Record 2 of Set 7 | svetlaya
# Processing Record 3 of Set 7 | pemberton
# Processing Record 4 of Set 7 | gubkinskiy
# Processing Record 5 of Set 7 | isla vista
# Processing Record 6 of Set 7 | morgan city
# Processing Record 7 of Set 7 | winchester
# Processing Record 8 of Set 7 | catemaco
# Processing Record 9 of Set 7 | qaqortoq
# Processing Record 10 of Set 7 | saint paul
# Processing Record 11 of Set 7 | edd
# Processing Record 12 of Set 7 | soe
# Processing Record 13 of Set 7 | kahului
# Processing Record 14 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 7 | port hedland
# Processing Record 16 of Set 7 | macusani
# Processing Record 17 of Set 7 | tilichiki
# Processing Record 18 of Set 7 | boddam
# Processing Record 19 of Set 7 | vanavara
# Processing Record 20 of Set 7 | gorokhovets
# Processing Record 21 of Set 7 | vologda
# Processing Record 22 of Set 7 | goderich
# Processing Record 23 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 24 of Set 7 | san policarpo
# Processing Record 25 of Set 7 | antigonish
# Processing Record 26 of Set 7 | luena
# Processing Record 27 of Set 7 | beyneu
# Processing Record 28 of Set 7 | north myrtle beach
# Processing Record 29 of Set 7 | mackenzie
# Processing Record 30 of Set 7 | semnan
# Processing Record 31 of Set 7 | dahanu
# Processing Record 32 of Set 7 | ajaccio
# Processing Record 33 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 7 | moranbah
# Processing Record 35 of Set 7 | wamba
# Processing Record 36 of Set 7 | chernyshevskiy
# Processing Record 37 of Set 7 | coahuayana
# Processing Record 38 of Set 7 | labuan
# Processing Record 39 of Set 7 | thinadhoo
# Processing Record 40 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 7 | kruisfontein
# Processing Record 42 of Set 7 | bima
# Processing Record 43 of Set 7 | souillac
# Processing Record 44 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 7 | wanxian
# Processing Record 46 of Set 7 | tvoroyri
# Processing Record 47 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 7 | kamaishi
# Processing Record 49 of Set 7 | lavrentiya
# Processing Record 50 of Set 7 | sola
# Processing Record 1 of Set 8 | sao filipe
# Processing Record 2 of Set 8 | roma
# Processing Record 3 of Set 8 | grande prairie
# Processing Record 4 of Set 8 | norman wells
# Processing Record 5 of Set 8 | hamilton
# Processing Record 6 of Set 8 | namibe
# Processing Record 7 of Set 8 | port hardy
# Processing Record 8 of Set 8 | koutsouras
# Processing Record 9 of Set 8 | warrnambool
# Processing Record 10 of Set 8 | alugan
# Processing Record 11 of Set 8 | ust-omchug
# Processing Record 12 of Set 8 | khorixas
# Processing Record 13 of Set 8 | keta
# Processing Record 14 of Set 8 | jonesboro
# Processing Record 15 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 8 | pavilosta
# Processing Record 17 of Set 8 | chokurdakh
# Processing Record 18 of Set 8 | praia da vitoria
# Processing Record 19 of Set 8 | narsaq
# Processing Record 20 of Set 8 | victoria
# Processing Record 21 of Set 8 | piotrkow trybunalski
# Processing Record 22 of Set 8 | bharatpur
# Processing Record 23 of Set 8 | sterling
# Processing Record 24 of Set 8 | ketchikan
# Processing Record 25 of Set 8 | jawad
# Processing Record 26 of Set 8 | zabinka
# City not found. Skipping...
# Processing Record 27 of Set 8 | moerai
# Processing Record 28 of Set 8 | husavik
# Processing Record 29 of Set 8 | kalininsk
# Processing Record 30 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 8 | slave lake
# Processing Record 32 of Set 8 | gasa
# Processing Record 33 of Set 8 | jackson
# Processing Record 34 of Set 8 | ponta do sol
# Processing Record 35 of Set 8 | diego de almagro
# Processing Record 36 of Set 8 | waddan
# Processing Record 37 of Set 8 | melo
# Processing Record 38 of Set 8 | bijar
# Processing Record 39 of Set 8 | russell
# Processing Record 40 of Set 8 | tatarsk
# Processing Record 41 of Set 8 | cangucu
# Processing Record 42 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 8 | kathmandu
# Processing Record 44 of Set 8 | saint-leu
# Processing Record 45 of Set 8 | chapais
# Processing Record 46 of Set 8 | carutapera
# Processing Record 47 of Set 8 | caravelas
# Processing Record 48 of Set 8 | rjukan
# Processing Record 49 of Set 8 | biloela
# Processing Record 50 of Set 8 | nebaj
# Processing Record 1 of Set 9 | mandal
# Processing Record 2 of Set 9 | tsiroanomandidy
# Processing Record 3 of Set 9 | kushva
# Processing Record 4 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 9 | cordeiro
# Processing Record 6 of Set 9 | yining
# Processing Record 7 of Set 9 | gualeguaychu
# Processing Record 8 of Set 9 | phenix city
# Processing Record 9 of Set 9 | richards bay
# Processing Record 10 of Set 9 | krasnoselkup
# Processing Record 11 of Set 9 | acajutla
# Processing Record 12 of Set 9 | patos
# Processing Record 13 of Set 9 | haines junction
# Processing Record 14 of Set 9 | los llanos de aridane
# Processing Record 15 of Set 9 | solnechnyy
# Processing Record 16 of Set 9 | esfahan
# Processing Record 17 of Set 9 | adrar
# Processing Record 18 of Set 9 | kudahuvadhoo
# Processing Record 19 of Set 9 | bengkalis
# City not found. Skipping...
# Processing Record 20 of Set 9 | korla
# Processing Record 21 of Set 9 | selizharovo
# Processing Record 22 of Set 9 | anori
# Processing Record 23 of Set 9 | mahanoro
# Processing Record 24 of Set 9 | kitimat
# Processing Record 25 of Set 9 | ballina
# Processing Record 26 of Set 9 | ahualulco
# Processing Record 27 of Set 9 | mahibadhoo
# Processing Record 28 of Set 9 | saint anthony
# Processing Record 29 of Set 9 | luau
# Processing Record 30 of Set 9 | dera bugti
# Processing Record 31 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 9 | deputatskiy
# Processing Record 33 of Set 9 | komsomolskiy
# Processing Record 34 of Set 9 | odweyne
# Processing Record 35 of Set 9 | semirom
# Processing Record 36 of Set 9 | gawler
# Processing Record 37 of Set 9 | kataysk
# Processing Record 38 of Set 9 | paz de ariporo
# City not found. Skipping...
# Processing Record 39 of Set 9 | cabedelo
# Processing Record 40 of Set 9 | langsa
# Processing Record 41 of Set 9 | lyngseidet
# Processing Record 42 of Set 9 | makakilo city
# Processing Record 43 of Set 9 | freeport
# Processing Record 44 of Set 9 | ariquemes
# Processing Record 45 of Set 9 | vizinga
# Processing Record 46 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 9 | pyapon
# Processing Record 48 of Set 9 | sitka
# Processing Record 49 of Set 9 | hobyo
# Processing Record 50 of Set 9 | ihosy
# Processing Record 1 of Set 10 | vestmannaeyjar
# Processing Record 2 of Set 10 | tiznit
# Processing Record 3 of Set 10 | chifeng
# Processing Record 4 of Set 10 | dapdap
# Processing Record 5 of Set 10 | mitsamiouli
# Processing Record 6 of Set 10 | nhulunbuy
# Processing Record 7 of Set 10 | shache
# Processing Record 8 of Set 10 | forio
# Processing Record 9 of Set 10 | faya
# Processing Record 10 of Set 10 | ixtapa
# Processing Record 11 of Set 10 | vestmanna
# Processing Record 12 of Set 10 | aljezur
# Processing Record 13 of Set 10 | havre-saint-pierre
# Processing Record 14 of Set 10 | nishihara
# Processing Record 15 of Set 10 | narovchat
# Processing Record 16 of Set 10 | olavarria
# Processing Record 17 of Set 10 | touros
# Processing Record 18 of Set 10 | correntina
# Processing Record 19 of Set 10 | bayan
# Processing Record 20 of Set 10 | vrangel
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | duldurga
# Processing Record 23 of Set 10 | baykit
# Processing Record 24 of Set 10 | kitob
# Processing Record 25 of Set 10 | sokoto
# Processing Record 26 of Set 10 | kieta
# Processing Record 27 of Set 10 | klaksvik
# Processing Record 28 of Set 10 | klamath falls
# Processing Record 29 of Set 10 | benemerito de las americas
# Processing Record 30 of Set 10 | suntar
# Processing Record 31 of Set 10 | mumford
# Processing Record 32 of Set 10 | voh
# Processing Record 33 of Set 10 | katsuura
# Processing Record 34 of Set 10 | gornoye loo
# Processing Record 35 of Set 10 | francisco beltrao
# Processing Record 36 of Set 10 | sosnogorsk
# Processing Record 37 of Set 10 | lyuban
# Processing Record 38 of Set 10 | half moon bay
# Processing Record 39 of Set 10 | gavle
# Processing Record 40 of Set 10 | palencia
# Processing Record 41 of Set 10 | san quintin
# Processing Record 42 of Set 10 | valdivia
# Processing Record 43 of Set 10 | cap malheureux
# Processing Record 44 of Set 10 | chato
# Processing Record 45 of Set 10 | bundaberg
# Processing Record 46 of Set 10 | vyazemskiy
# Processing Record 47 of Set 10 | saint-augustin
# Processing Record 48 of Set 10 | sibolga
# Processing Record 49 of Set 10 | trincomalee
# Processing Record 50 of Set 10 | ler
# Processing Record 1 of Set 11 | erzin
# Processing Record 2 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 11 | goycay
# City not found. Skipping...
# Processing Record 4 of Set 11 | nome
# Processing Record 5 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 11 | erenhot
# Processing Record 7 of Set 11 | asyut
# Processing Record 8 of Set 11 | czluchow
# Processing Record 9 of Set 11 | linxia
# Processing Record 10 of Set 11 | ratnagiri
# Processing Record 11 of Set 11 | vila franca do campo
# Processing Record 12 of Set 11 | emet
# Processing Record 13 of Set 11 | pocone
# Processing Record 14 of Set 11 | pontes e lacerda
# Processing Record 15 of Set 11 | leningradskiy
# Processing Record 16 of Set 11 | torrington
# Processing Record 17 of Set 11 | aras
# Processing Record 18 of Set 11 | atherton
# Processing Record 19 of Set 11 | coutances
# Processing Record 20 of Set 11 | hjelset
# Processing Record 21 of Set 11 | walvis bay
# Processing Record 22 of Set 11 | belmonte
# Processing Record 23 of Set 11 | westport
# Processing Record 24 of Set 11 | hofn
# Processing Record 25 of Set 11 | malanje
# Processing Record 26 of Set 11 | agva
# City not found. Skipping...
# Processing Record 27 of Set 11 | cacu
# Processing Record 28 of Set 11 | sainte-marie
# Processing Record 29 of Set 11 | kloulklubed
# Processing Record 30 of Set 11 | boralday
# Processing Record 31 of Set 11 | buchanan
# Processing Record 32 of Set 11 | vila velha
# Processing Record 33 of Set 11 | arenapolis
# Processing Record 34 of Set 11 | zhuhai
# Processing Record 35 of Set 11 | handwara
# City not found. Skipping...
# Processing Record 36 of Set 11 | berlevag
# Processing Record 37 of Set 11 | namwala
# Processing Record 38 of Set 11 | khandyga
# Processing Record 39 of Set 11 | borama
# City not found. Skipping...
# Processing Record 40 of Set 11 | falun
# Processing Record 41 of Set 11 | yeehaw junction
# City not found. Skipping...
# Processing Record 42 of Set 11 | ternate
# Processing Record 43 of Set 11 | puerto madryn
# Processing Record 44 of Set 11 | la rioja
# Processing Record 45 of Set 11 | talcahuano
# Processing Record 46 of Set 11 | muriwai beach
# Processing Record 47 of Set 11 | am timan
# Processing Record 48 of Set 11 | alagoinhas
# Processing Record 49 of Set 11 | moanda
# Processing Record 50 of Set 11 | storforshei
# Processing Record 1 of Set 12 | muravlenko
# Processing Record 2 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 3 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 12 | herend
# Processing Record 5 of Set 12 | riyadh
# Processing Record 6 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 12 | whitehorse
# Processing Record 8 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 12 | baijiantan
# Processing Record 10 of Set 12 | matagami
# Processing Record 11 of Set 12 | rio grande
# Processing Record 12 of Set 12 | lata
# Processing Record 13 of Set 12 | shingu
# Processing Record 14 of Set 12 | hovd
# Processing Record 15 of Set 12 | udaipura
# Processing Record 16 of Set 12 | saint-francois
# Processing Record 17 of Set 12 | pucallpa
# Processing Record 18 of Set 12 | ochakiv
# Processing Record 19 of Set 12 | khor
# Processing Record 20 of Set 12 | izazi
# Processing Record 21 of Set 12 | umm kaddadah
# Processing Record 22 of Set 12 | kroya
# Processing Record 23 of Set 12 | izumo
# Processing Record 24 of Set 12 | margate
# Processing Record 25 of Set 12 | nantucket
# Processing Record 26 of Set 12 | shenjiamen
# Processing Record 27 of Set 12 | hope
# Processing Record 28 of Set 12 | tahta
# Processing Record 29 of Set 12 | loughrea
# Processing Record 30 of Set 12 | north bend
# Processing Record 31 of Set 12 | ambon
# Processing Record 32 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 12 | mmabatho
# Processing Record 34 of Set 12 | mayumba
# Processing Record 35 of Set 12 | ekhabi
# Processing Record 36 of Set 12 | orbetello
# Processing Record 37 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 38 of Set 12 | morales
# Processing Record 39 of Set 12 | hongan
# City not found. Skipping...
# Processing Record 40 of Set 12 | tura
# Processing Record 41 of Set 12 | strathpeffer
# Processing Record 42 of Set 12 | corinto
# Processing Record 43 of Set 12 | geraldton
# Processing Record 44 of Set 12 | lakatoro
# Processing Record 45 of Set 12 | sao borja
# Processing Record 46 of Set 12 | lubango
# Processing Record 47 of Set 12 | verkhnyaya inta
# Processing Record 48 of Set 12 | barguzin
# Processing Record 49 of Set 12 | altamira
# Processing Record 50 of Set 12 | bilma
# Processing Record 1 of Set 13 | saint-joseph
# Processing Record 2 of Set 13 | abrau-dyurso
# Processing Record 3 of Set 13 | djibo
# Processing Record 4 of Set 13 | sampit
# Processing Record 5 of Set 13 | dunmore town
# Processing Record 6 of Set 13 | san juan
# Processing Record 7 of Set 13 | kaeo
# Processing Record 8 of Set 13 | iquitos
# Processing Record 9 of Set 13 | villa carlos paz
# Processing Record 10 of Set 13 | flin flon
# Processing Record 11 of Set 13 | kwinana
# Processing Record 12 of Set 13 | meulaboh
# Processing Record 13 of Set 13 | kangasala
# Processing Record 14 of Set 13 | kutahya
# Processing Record 15 of Set 13 | huilong
# Processing Record 16 of Set 13 | senno
# Processing Record 17 of Set 13 | hambantota
# Processing Record 18 of Set 13 | tabou
# Processing Record 19 of Set 13 | ritchie
# Processing Record 20 of Set 13 | taganak
# Processing Record 21 of Set 13 | oriximina
# Processing Record 22 of Set 13 | sur
# Processing Record 23 of Set 13 | palmerston north
# Processing Record 24 of Set 13 | yerbogachen
# Processing Record 25 of Set 13 | porto santo
# Processing Record 26 of Set 13 | fort nelson
# Processing Record 27 of Set 13 | tautira
# Processing Record 28 of Set 13 | porto seguro
# Processing Record 29 of Set 13 | brae
# Processing Record 30 of Set 13 | ngunguru
# Processing Record 31 of Set 13 | podor
# Processing Record 32 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 13 | amga
# Processing Record 34 of Set 13 | mae sai
# Processing Record 35 of Set 13 | lamar
# Processing Record 36 of Set 13 | santiago del estero
# Processing Record 37 of Set 13 | kuala krai
# City not found. Skipping...
# Processing Record 38 of Set 13 | turukhansk
# Processing Record 39 of Set 13 | kelvington
# Processing Record 40 of Set 13 | marolambo
# Processing Record 41 of Set 13 | klyuchevskiy
# Processing Record 42 of Set 13 | dabat
# Processing Record 43 of Set 13 | toul
# Processing Record 44 of Set 13 | castro-urdiales
# Processing Record 45 of Set 13 | smithers
# Processing Record 46 of Set 13 | manjeshwar
# Processing Record 47 of Set 13 | chisec
# Processing Record 48 of Set 13 | havoysund
# Processing Record 49 of Set 13 | mugur-aksy
# Processing Record 50 of Set 13 | yar-sale
# Processing Record 1 of Set 14 | avera
# Processing Record 2 of Set 14 | channel-port aux basques
# Processing Record 3 of Set 14 | san clemente
# Processing Record 4 of Set 14 | talnakh
# Processing Record 5 of Set 14 | mattru
# Processing Record 6 of Set 14 | macae
# Processing Record 7 of Set 14 | jibuti
# Processing Record 8 of Set 14 | doka
# Processing Record 9 of Set 14 | norwalk
# Processing Record 10 of Set 14 | keti bandar
# Processing Record 11 of Set 14 | port-cartier
# Processing Record 12 of Set 14 | amapa
# Processing Record 13 of Set 14 | aborlan
# Processing Record 14 of Set 14 | kokopo
# Processing Record 15 of Set 14 | arlit
# Processing Record 16 of Set 14 | necochea
# Processing Record 17 of Set 14 | antofagasta
# Processing Record 18 of Set 14 | dimona
# Processing Record 19 of Set 14 | venice
# Processing Record 20 of Set 14 | vangazi
# Processing Record 21 of Set 14 | presidencia roque saenz pena
# Processing Record 22 of Set 14 | kosai
# Processing Record 23 of Set 14 | samarai
# Processing Record 24 of Set 14 | villa guerrero
# Processing Record 25 of Set 14 | lapua
# Processing Record 26 of Set 14 | sokyryany
# Processing Record 27 of Set 14 | borogontsy
# Processing Record 28 of Set 14 | belokurikha
# Processing Record 29 of Set 14 | locri
# Processing Record 30 of Set 14 | melnikovo
# Processing Record 31 of Set 14 | anshun
# Processing Record 32 of Set 14 | marovoay
# Processing Record 33 of Set 14 | arrecife
# Processing Record 34 of Set 14 | la paz
# Processing Record 35 of Set 14 | alice springs
# Processing Record 36 of Set 14 | capiata
# Processing Record 37 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 14 | milyutinskaya
# Processing Record 39 of Set 14 | ushumun
# Processing Record 40 of Set 14 | ankazoabo
# Processing Record 41 of Set 14 | the valley
# Processing Record 42 of Set 14 | novoagansk
# Processing Record 43 of Set 14 | bowen
# Processing Record 44 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 14 | yumen
# Processing Record 46 of Set 14 | toulepleu
# City not found. Skipping...
# Processing Record 47 of Set 14 | wajir
# Processing Record 48 of Set 14 | koungou
# Processing Record 49 of Set 14 | mokhsogollokh
# Processing Record 50 of Set 14 | bandarbeyla
# Processing Record 1 of Set 15 | camana
# Processing Record 2 of Set 15 | klaipeda
# Processing Record 3 of Set 15 | kardla
# Processing Record 4 of Set 15 | galesong
# Processing Record 5 of Set 15 | pastos bons
# Processing Record 6 of Set 15 | hirara
# Processing Record 7 of Set 15 | ust-nera
# Processing Record 8 of Set 15 | jipijapa
# Processing Record 9 of Set 15 | morant bay
# Processing Record 10 of Set 15 | lipari
# Processing Record 11 of Set 15 | daloa
# Processing Record 12 of Set 15 | yazoo city
# Processing Record 13 of Set 15 | paita
# Processing Record 14 of Set 15 | noshiro
# Processing Record 15 of Set 15 | ladario
# Processing Record 16 of Set 15 | eyl
# Processing Record 17 of Set 15 | sao felix do xingu
# Processing Record 18 of Set 15 | oktyabrskoye
# Processing Record 19 of Set 15 | srandakan
# Processing Record 20 of Set 15 | mali
# Processing Record 21 of Set 15 | hohhot
# Processing Record 22 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 15 | puerto baquerizo moreno
# Processing Record 24 of Set 15 | swellendam
# Processing Record 25 of Set 15 | ekimchan
# Processing Record 26 of Set 15 | balkanabat
# Processing Record 27 of Set 15 | mehamn
# Processing Record 28 of Set 15 | xining
# Processing Record 29 of Set 15 | denpasar
# Processing Record 30 of Set 15 | guadalupe y calvo
# Processing Record 31 of Set 15 | mandi bahauddin
# Processing Record 32 of Set 15 | noumea
# Processing Record 33 of Set 15 | nouakchott
# Processing Record 34 of Set 15 | nokaneng
# Processing Record 35 of Set 15 | piacabucu
# Processing Record 36 of Set 15 | chastyye
# Processing Record 37 of Set 15 | shunyi
# Processing Record 38 of Set 15 | portland
# Processing Record 39 of Set 15 | bay roberts
# Processing Record 40 of Set 15 | anjozorobe
# Processing Record 41 of Set 15 | shemursha
# Processing Record 42 of Set 15 | kolpashevo
# Processing Record 43 of Set 15 | boca do acre
# Processing Record 44 of Set 15 | akureyri
# Processing Record 45 of Set 15 | de aar
# Processing Record 46 of Set 15 | baoying
# Processing Record 47 of Set 15 | ambagarh chauki
# Processing Record 48 of Set 15 | adeje
# Processing Record 49 of Set 15 | mao
# Processing Record 50 of Set 15 | lexington
# Processing Record 1 of Set 16 | sangin
# Processing Record 2 of Set 16 | gat
# Processing Record 3 of Set 16 | nurobod
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 692

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Quijingue -10.7525  -39.2092     70.81        97          97        4.94
# 1  High Level  58.5169 -117.1360     17.71        73         100       10.36
# 2       Vaini -21.2000 -175.2000     84.36        84          75        6.91
# 3      Atuona  -9.8000 -139.0333     79.65        78           8       17.07
# 4     Kosamba  21.4833   72.9500     78.71        74           0        5.44
# 5    Tasiilaq  65.6145  -37.6368     33.19        97         100        9.44
# 6       Gamba  -2.6500   10.0000     77.31        92         100        3.89
# 7   Busselton -33.6500  115.3333     59.31        66          67        3.00
# 8  Bredasdorp -34.5322   20.0403     60.22        92          81        4.72
# 9      Olinda  -8.0089  -34.8553     83.93        65          20        9.22
#
#   Country Current Description
# 0      BR     overcast clouds
# 1      CA          light snow
# 2      TO       broken clouds
# 3      PF           clear sky
# 4      IN           clear sky
# 5      GL          light snow
# 6      GA     overcast clouds
# 7      AU       broken clouds
# 8      ZA       broken clouds
# 9      BR          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Quijingue      BR -10.7525  -39.2092     70.81        97          97
# 1  High Level      CA  58.5169 -117.1360     17.71        73         100
# 2       Vaini      TO -21.2000 -175.2000     84.36        84          75
# 3      Atuona      PF  -9.8000 -139.0333     79.65        78           8
# 4     Kosamba      IN  21.4833   72.9500     78.71        74           0
# 5    Tasiilaq      GL  65.6145  -37.6368     33.19        97         100
# 6       Gamba      GA  -2.6500   10.0000     77.31        92         100
# 7   Busselton      AU -33.6500  115.3333     59.31        66          67
# 8  Bredasdorp      ZA -34.5322   20.0403     60.22        92          81
# 9      Olinda      BR  -8.0089  -34.8553     83.93        65          20
#
#    Wind Speed Current Description
# 0        4.94     overcast clouds
# 1       10.36          light snow
# 2        6.91       broken clouds
# 3       17.07           clear sky
# 4        5.44           clear sky
# 5        9.44          light snow
# 6        3.89     overcast clouds
# 7        3.00       broken clouds
# 8        4.72       broken clouds
# 9        9.22          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
