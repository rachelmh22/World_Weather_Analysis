# %%
import sys
# !{sys.executable} -m pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 3.9 MB/s eta 0:00:01
# Requirement already satisfied: ipython>=5.3.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.29.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (5.1.0)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: appnope in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.18.0)
# Requirement already satisfied: pygments in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (2.10.0)
# Requirement already satisfied: pexpect>4.3 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: decorator in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (5.1.0)
# Requirement already satisfied: pickleshare in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (58.0.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (6.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.2)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.5)
# Requirement already satisfied: argon2-cffi in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: nbconvert in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.4)
# Requirement already satisfied: prometheus-client in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: jinja2 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: cffi>=1.0.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.6)
# Requirement already satisfied: pycparser in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: defusedxml in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.0.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: testpath in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: nest-asyncio in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: async-generator in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: webencodings in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: packaging in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/rachelhuang/opt/anaconda3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py) ... done
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076111 sha256=670f86e1f5de861441254b3561733e4cb1c7478ecb8c6ec3bcac681a9fde34b4
#   Stored in directory: /Users/rachelhuang/Library/Caches/pip/wheels/66/ab/29/3032938612273665f0fa4d2fab4e3ecfe86480eaaa40aaee91
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID             City Country                 Date      Lat       Lng  \
# 0        0      Yerbogachen      RU  2022-04-06 22:35:55  61.2767  108.0108
# 1        1           Beloha      MG  2022-04-06 22:35:57 -25.1667   45.0500
# 2        2      New Norfolk      AU  2022-04-06 22:35:57 -42.7826  147.0587
# 3        3  Arraial Do Cabo      BR  2022-04-06 22:35:58 -22.9661  -42.0278
# 4        4           Domoni      KM  2022-04-06 22:35:58 -12.2569   44.5319
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     28.22        98         100        3.69
# 1     72.07        94          22        1.57
# 2     51.93        69           0        2.06
# 3     75.16        94          75       11.50
# 4     79.11        83          73        2.80

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
##fig = gmaps.figure()
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
##heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
##heat_layer = gmaps.heatmap_layer(locations, weights=temps)
heat_layer = heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country                 Date      Lat       Lng  \
# 3         3  Arraial Do Cabo      BR  2022-04-06 22:35:58 -22.9661  -42.0278
# 4         4           Domoni      KM  2022-04-06 22:35:58 -12.2569   44.5319
# 6         6     Saint-Pierre      RE  2022-04-06 22:35:59 -21.3393   55.4781
# 15       15          Veraval      IN  2022-04-06 22:36:02  20.9000   70.3667
# 17       17          Rikitea      PF  2022-04-06 22:31:26 -23.1203 -134.9692
# 27       27           Avarua      CK  2022-04-06 22:36:06 -21.2078 -159.7750
# 29       29              Eyl      SO  2022-04-06 22:36:06   7.9803   49.8164
# 36       36            Natal      BR  2022-04-06 22:31:59  -5.7950  -35.2094
# 38       38       Georgetown      MY  2022-04-06 22:33:11   5.4112  100.3354
# 40       40          Kapoeta      SS  2022-04-06 22:36:10   4.7717   33.5903
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 3      75.16        94          75       11.50
# 4      79.11        83          73        2.80
# 6      78.48        81         100       17.27
# 15     78.62        70          40       12.10
# 17     78.75        69          56       10.87
# 27     84.25        79          40       16.11
# 29     77.68        77           2       10.11
# 36     80.82        89          40        8.05
# 38     78.73        98          20        2.30
# 40     85.19        39          30       17.63

# %%
preferred_cities_df.count()
# Out:
# City_ID       187
# City          187
# Country       187
# Date          187
# Lat           187
# Lng           187
# Max Temp      187
# Humidity      187
# Cloudiness    187
# Wind Speed    187
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp      Lat       Lng Hotel Name
# 3   Arraial Do Cabo      BR     75.16 -22.9661  -42.0278
# 4            Domoni      KM     79.11 -12.2569   44.5319
# 6      Saint-Pierre      RE     78.48 -21.3393   55.4781
# 15          Veraval      IN     78.62  20.9000   70.3667
# 17          Rikitea      PF     78.75 -23.1203 -134.9692
# 27           Avarua      CK     84.25 -21.2078 -159.7750
# 29              Eyl      SO     77.68   7.9803   49.8164
# 36            Natal      BR     80.82  -5.7950  -35.2094
# 38       Georgetown      MY     78.73   5.4112  100.3354
# 40          Kapoeta      SS     85.19   4.7717   33.5903

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    ##hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df
# Out:
#                 City Country  Max Temp      Lat       Lng  \
# 3    Arraial Do Cabo      BR     75.16 -22.9661  -42.0278
# 4             Domoni      KM     79.11 -12.2569   44.5319
# 6       Saint-Pierre      RE     78.48 -21.3393   55.4781
# 15           Veraval      IN     78.62  20.9000   70.3667
# 17           Rikitea      PF     78.75 -23.1203 -134.9692
# ..               ...     ...       ...      ...       ...
# 548        Cansancao      BR     80.44 -10.6672  -39.4992
# 551    San Policarpo      PH     78.48  12.1791  125.5072
# 553             Ocos      GT     84.97  14.5094  -92.1933
# 554          Emerald      AU     75.34 -23.5333  148.1667
# 555            Jesup      US     82.33  31.6074  -81.8854
#
#                 Hotel Name
# 3      Pousada Porto Praia
# 4                Al Djadid
# 6            Lindsey Hôtel
# 15       Lords Inn Somnath
# 17         People ThankYou
# ..                     ...
# 548                 MIGUEL
# 551      Agapita M. Nicart
# 553  Auto Hotel El Soñador
# 554      The Irish Village
# 555          Western Motel
#
# [187 rows x 6 columns]

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
